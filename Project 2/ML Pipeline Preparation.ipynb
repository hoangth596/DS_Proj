# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import re
import pickle
import pandas as pd 
from sqlalchemy import create_engine
import nltk 
from nltk.tokenize import word_tokenize 
from nltk.corpus import stopwords 
from nltk.stem import WordNetLemmatizer
from sklearn.pipeline import Pipeline 
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.multioutput import MultiOutputClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.model_selection import train_test_split,  GridSearchCV 
from sklearn.metrics import classification_report


nltk.download(['wordnet', 'punkt', 'stopwords'])
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# load data from database

engine = create_engine('sqlite:///HoangDB.db')
df = pd.read_sql_table('disaster_messages', engine)

X = df['message']  # Message Column
Y = df.iloc[:, 4:] # Classification label

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    """
    Function: split text into words and return the root form of the words
    Args:
      text(str): the message
    Return:
      lemm(list of str): a list of the root form of the message words
    """
    # Normalize text
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower())
    
    # Tokenize text
    words = word_tokenize(text)
    
    # Remove stop words
    stop = stopwords.words("english")
    words = [t for t in words if t not in stop]
    
    # Lemmatization
    lemm = [WordNetLemmatizer().lemmatize(w) for w in words]
    return lemm

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
# Pipleine 1: Random Forest Classifier

pipeline_rfc = Pipeline([
        ('vect', CountVectorizer(tokenizer = tokenize)),
        ('tfidf', TfidfTransformer()),
        ('clf',  MultiOutputClassifier(RandomForestClassifier()))
    ])


# Pipeline 2: Naive Bayes classifier

pipeline_nbc = Pipeline([
        ('vect', CountVectorizer(tokenizer = tokenize)),
        ('tfidf', TfidfTransformer()),
        ('clf',  MultiOutputClassifier(MultinomialNB()))
    ])


# Pipleine 3: Adaboost Classifier 

pipeline_ada = Pipeline([
        ('vect', CountVectorizer(tokenizer = tokenize)),
        ('tfidf', TfidfTransformer()),
        ('clf',  MultiOutputClassifier(AdaBoostClassifier()))
    ])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
# Spiliting data
X_train, X_test, y_train, y_test = train_test_split(X, Y)

pipeline_rfc.fit(X_train, y_train)
pipeline_nbc.fit(X_train, y_train)
pipeline_ada.fit(X_train, y_train)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/naive_bayes.py:461: RuntimeWarning: divide by zero encountered in log
#   self.class_log_prior_ = (np.log(self.class_count_) -
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...mator=None,
#           learning_rate=1.0, n_estimators=50, random_state=None),
#            n_jobs=1))])

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
def plot_scores(y_test, y_pred):
    #Testing the model
    # Printing the classification report for each label
    i = 0
    for col in y_test:
        print('Feature {}: {}'.format(i+1, col))
        print(classification_report(y_test[col], y_pred[:, i]))
        i = i + 1
    accuracy = (y_pred == y_test.values).mean()
    print('The model accuracy is {:.3f}'.format(accuracy))

# %%
# Prediction: the Random Forest Classifier  
y_pred = pipeline_rfc.predict(X_test)
plot_scores(y_test, y_pred)
# Out:
# Feature 1: related
#              precision    recall  f1-score   support
#
#           0       0.62      0.44      0.52      1536
#           1       0.84      0.91      0.88      4979
#           2       0.21      0.51      0.30        39
#
# avg / total       0.79      0.80      0.79      6554
#
# Feature 2: request
#              precision    recall  f1-score   support
#
#           0       0.89      0.98      0.93      5409
#           1       0.80      0.44      0.57      1145
#
# avg / total       0.88      0.88      0.87      6554
#
# Feature 3: offer
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6528
#           1       0.00      0.00      0.00        26
#
# avg / total       0.99      1.00      0.99      6554
#
# Feature 4: aid_related
#              precision    recall  f1-score   support
#
#           0       0.75      0.86      0.80      3844
#           1       0.75      0.59      0.66      2710
#
# avg / total       0.75      0.75      0.74      6554
#
# Feature 5: medical_help
#              precision    recall  f1-score   support
#
#           0       0.93      0.99      0.96      6021
#           1       0.62      0.10      0.18       533
#
# avg / total       0.90      0.92      0.90      6554
#
# Feature 6: medical_products
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6245
#           1       0.78      0.09      0.17       309
#
# avg / total       0.95      0.96      0.94      6554
#
# Feature 7: search_and_rescue
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.99      6361
#           1       0.67      0.09      0.16       193
#
# avg / total       0.96      0.97      0.96      6554
#
# Feature 8: security
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6423
#           1       0.00      0.00      0.00       131
#
# avg / total       0.96      0.98      0.97      6554
#
# Feature 9: military
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6318
#           1       0.74      0.07      0.13       236
#
# avg / total       0.96      0.97      0.95      6554
#
# Feature 10: child_alone
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# Feature 11: water
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6143
#           1       0.86      0.28      0.43       411
#
# avg / total       0.95      0.95      0.94      6554
#
# Feature 12: food
#              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.96      5812
#           1       0.84      0.50      0.63       742
#
# avg / total       0.93      0.93      0.93      6554
#
# Feature 13: shelter
#              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.96      5966
#           1       0.83      0.33      0.48       588
#
# avg / total       0.93      0.93      0.92      6554
#
# Feature 14: clothing
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6463
#           1       0.88      0.08      0.14        91
#
# avg / total       0.99      0.99      0.98      6554
#
# Feature 15: money
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6409
#           1       0.76      0.09      0.16       145
#
# avg / total       0.98      0.98      0.97      6554
#
# Feature 16: missing_people
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6487
#           1       1.00      0.01      0.03        67
#
# avg / total       0.99      0.99      0.99      6554
#
# Feature 17: refugees
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6341
#           1       0.50      0.03      0.05       213
#
# avg / total       0.95      0.97      0.95      6554
#
# Feature 18: death
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6278
#           1       0.76      0.15      0.25       276
#
# avg / total       0.96      0.96      0.95      6554
#
# Feature 19: other_aid
#              precision    recall  f1-score   support
#
#           0       0.87      0.99      0.93      5702
#           1       0.50      0.05      0.09       852
#
# avg / total       0.83      0.87      0.82      6554
#
# Feature 20: infrastructure_related
#              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6137
#           1       0.12      0.00      0.01       417
#
# avg / total       0.88      0.93      0.91      6554
#
# Feature 21: transport
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6254
#           1       0.71      0.07      0.12       300
#
# avg / total       0.95      0.96      0.94      6554
#
# Feature 22: buildings
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6218
#           1       0.72      0.09      0.16       336
#
# avg / total       0.94      0.95      0.93      6554
#
# Feature 23: electricity
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6422
#           1       0.83      0.08      0.14       132
#
# avg / total       0.98      0.98      0.97      6554
#
# Feature 24: tools
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6509
#           1       0.00      0.00      0.00        45
#
# avg / total       0.99      0.99      0.99      6554
#
# Feature 25: hospitals
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6470
#           1       0.00      0.00      0.00        84
#
# avg / total       0.97      0.99      0.98      6554
#
# Feature 26: shops
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6532
#           1       0.00      0.00      0.00        22
#
# avg / total       0.99      1.00      0.99      6554
#
# Feature 27: aid_centers
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6482
#           1       0.00      0.00      0.00        72
#
# avg / total       0.98      0.99      0.98      6554
#
# Feature 28: other_infrastructure
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6286
#           1       0.08      0.00      0.01       268
#
# avg / total       0.92      0.96      0.94      6554
#
# Feature 29: weather_related
#              precision    recall  f1-score   support
#
#           0       0.87      0.95      0.91      4732
#           1       0.84      0.62      0.71      1822
#
# avg / total       0.86      0.86      0.85      6554
#
# Feature 30: floods
#              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6008
#           1       0.91      0.32      0.47       546
#
# avg / total       0.94      0.94      0.93      6554
#
# Feature 31: storm
#              precision    recall  f1-score   support
#
#           0       0.95      0.99      0.97      5970
#           1       0.77      0.45      0.56       584
#
# avg / total       0.93      0.94      0.93      6554
#
# Feature 32: fire
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6468
#           1       0.50      0.01      0.02        86
#
# avg / total       0.98      0.99      0.98      6554
#
# Feature 33: earthquake
#              precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98      5942
#           1       0.87      0.69      0.77       612
#
# avg / total       0.96      0.96      0.96      6554
#
# Feature 34: cold
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6422
#           1       0.62      0.08      0.14       132
#
# avg / total       0.97      0.98      0.97      6554
#
# Feature 35: other_weather
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6222
#           1       0.58      0.04      0.08       332
#
# avg / total       0.93      0.95      0.93      6554
#
# Feature 36: direct_report
#              precision    recall  f1-score   support
#
#           0       0.86      0.97      0.91      5264
#           1       0.77      0.34      0.47      1290
#
# avg / total       0.84      0.85      0.82      6554
#
# The model accuracy is 0.945
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# Prediction: the Naive Bayes classifier 
y_pred = pipeline_nbc.predict(X_test)
plot_scores(y_test, y_pred)
# Out:
# Feature 1: related
#              precision    recall  f1-score   support
#
#           0       0.80      0.09      0.16      1536
#           1       0.77      0.99      0.87      4979
#           2       0.00      0.00      0.00        39
#
# avg / total       0.78      0.78      0.70      6554
#
# Feature 2: request
#              precision    recall  f1-score   support
#
#           0       0.86      0.99      0.92      5409
#           1       0.87      0.22      0.36      1145
#
# avg / total       0.86      0.86      0.82      6554
#
# Feature 3: offer
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6528
#           1       0.00      0.00      0.00        26
#
# avg / total       0.99      1.00      0.99      6554
#
# Feature 4: aid_related
#              precision    recall  f1-score   support
#
#           0       0.76      0.84      0.80      3844
#           1       0.74      0.63      0.68      2710
#
# avg / total       0.75      0.75      0.75      6554
#
# Feature 5: medical_help
#              precision    recall  f1-score   support
#
#           0       0.92      1.00      0.96      6021
#           1       0.00      0.00      0.00       533
#
# avg / total       0.84      0.92      0.88      6554
#
# Feature 6: medical_products
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6245
#           1       0.00      0.00      0.00       309
#
# avg / total       0.91      0.95      0.93      6554
#
# Feature 7: search_and_rescue
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.99      6361
#           1       0.00      0.00      0.00       193
#
# avg / total       0.94      0.97      0.96      6554
#
# Feature 8: security
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6423
#           1       0.00      0.00      0.00       131
#
# avg / total       0.96      0.98      0.97      6554
#
# Feature 9: military
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6318
#           1       0.00      0.00      0.00       236
#
# avg / total       0.93      0.96      0.95      6554
#
# Feature 10: child_alone
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# Feature 11: water
#              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6143
#           1       0.00      0.00      0.00       411
#
# avg / total       0.88      0.94      0.91      6554
#
# Feature 12: food
#              precision    recall  f1-score   support
#
#           0       0.89      1.00      0.94      5812
#           1       0.80      0.02      0.03       742
#
# avg / total       0.88      0.89      0.84      6554
#
# Feature 13: shelter
#              precision    recall  f1-score   support
#
#           0       0.91      1.00      0.95      5966
#           1       0.00      0.00      0.00       588
#
# avg / total       0.83      0.91      0.87      6554
#
# Feature 14: clothing
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6463
#           1       0.00      0.00      0.00        91
#
# avg / total       0.97      0.99      0.98      6554
#
# Feature 15: money
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6409
#           1       0.00      0.00      0.00       145
#
# avg / total       0.96      0.98      0.97      6554
#
# Feature 16: missing_people
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6487
#           1       0.00      0.00      0.00        67
#
# avg / total       0.98      0.99      0.98      6554
#
# Feature 17: refugees
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6341
#           1       0.00      0.00      0.00       213
#
# avg / total       0.94      0.97      0.95      6554
#
# Feature 18: death
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6278
#           1       0.00      0.00      0.00       276
#
# avg / total       0.92      0.96      0.94      6554
#
# Feature 19: other_aid
#              precision    recall  f1-score   support
#
#           0       0.87      1.00      0.93      5702
#           1       0.00      0.00      0.00       852
#
# avg / total       0.76      0.87      0.81      6554
#
# Feature 20: infrastructure_related
#              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6137
#           1       0.00      0.00      0.00       417
#
# avg / total       0.88      0.94      0.91      6554
#
# Feature 21: transport
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6254
#           1       0.00      0.00      0.00       300
#
# avg / total       0.91      0.95      0.93      6554
#
# Feature 22: buildings
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6218
#           1       0.00      0.00      0.00       336
#
# avg / total       0.90      0.95      0.92      6554
#
# Feature 23: electricity
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6422
#           1       0.00      0.00      0.00       132
#
# avg / total       0.96      0.98      0.97      6554
#
# Feature 24: tools
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6509
#           1       0.00      0.00      0.00        45
#
# avg / total       0.99      0.99      0.99      6554
#
# Feature 25: hospitals
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6470
#           1       0.00      0.00      0.00        84
#
# avg / total       0.97      0.99      0.98      6554
#
# Feature 26: shops
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6532
#           1       0.00      0.00      0.00        22
#
# avg / total       0.99      1.00      0.99      6554
#
# Feature 27: aid_centers
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6482
#           1       0.00      0.00      0.00        72
#
# avg / total       0.98      0.99      0.98      6554
#
# Feature 28: other_infrastructure
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6286
#           1       0.00      0.00      0.00       268
#
# avg / total       0.92      0.96      0.94      6554
#
# Feature 29: weather_related
#              precision    recall  f1-score   support
#
#           0       0.81      0.98      0.88      4732
#           1       0.86      0.40      0.55      1822
#
# avg / total       0.82      0.82      0.79      6554
#
# Feature 30: floods
#              precision    recall  f1-score   support
#
#           0       0.92      1.00      0.96      6008
#           1       1.00      0.00      0.01       546
#
# avg / total       0.92      0.92      0.88      6554
#
# Feature 31: storm
#              precision    recall  f1-score   support
#
#           0       0.91      1.00      0.95      5970
#           1       0.88      0.01      0.02       584
#
# avg / total       0.91      0.91      0.87      6554
#
# Feature 32: fire
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6468
#           1       0.00      0.00      0.00        86
#
# avg / total       0.97      0.99      0.98      6554
#
# Feature 33: earthquake
#              precision    recall  f1-score   support
#
#           0       0.91      1.00      0.95      5942
#           1       0.87      0.10      0.18       612
#
# avg / total       0.91      0.91      0.88      6554
#
# Feature 34: cold
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6422
#           1       0.00      0.00      0.00       132
#
# avg / total       0.96      0.98      0.97      6554
#
# Feature 35: other_weather
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6222
#           1       0.00      0.00      0.00       332
#
# avg / total       0.90      0.95      0.92      6554
#
# Feature 36: direct_report
#              precision    recall  f1-score   support
#
#           0       0.83      0.99      0.90      5264
#           1       0.82      0.16      0.27      1290
#
# avg / total       0.83      0.83      0.78      6554
#
# The model accuracy is 0.936
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# Prediction: the Adaboost Classifier 
y_pred = pipeline_ada.predict(X_test)
plot_scores(y_test, y_pred)
# Out:
# Feature 1: related
#              precision    recall  f1-score   support
#
#           0       0.67      0.14      0.23      1536
#           1       0.78      0.98      0.87      4979
#           2       0.46      0.15      0.23        39
#
# avg / total       0.76      0.78      0.72      6554
#
# Feature 2: request
#              precision    recall  f1-score   support
#
#           0       0.91      0.97      0.94      5409
#           1       0.78      0.55      0.65      1145
#
# avg / total       0.89      0.89      0.89      6554
#
# Feature 3: offer
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6528
#           1       0.00      0.00      0.00        26
#
# avg / total       0.99      0.99      0.99      6554
#
# Feature 4: aid_related
#              precision    recall  f1-score   support
#
#           0       0.77      0.86      0.81      3844
#           1       0.75      0.63      0.69      2710
#
# avg / total       0.76      0.76      0.76      6554
#
# Feature 5: medical_help
#              precision    recall  f1-score   support
#
#           0       0.94      0.98      0.96      6021
#           1       0.60      0.25      0.36       533
#
# avg / total       0.91      0.93      0.91      6554
#
# Feature 6: medical_products
#              precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98      6245
#           1       0.70      0.31      0.43       309
#
# avg / total       0.95      0.96      0.95      6554
#
# Feature 7: search_and_rescue
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6361
#           1       0.64      0.19      0.29       193
#
# avg / total       0.97      0.97      0.97      6554
#
# Feature 8: security
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6423
#           1       0.26      0.04      0.07       131
#
# avg / total       0.97      0.98      0.97      6554
#
# Feature 9: military
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98      6318
#           1       0.62      0.36      0.46       236
#
# avg / total       0.96      0.97      0.97      6554
#
# Feature 10: child_alone
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# Feature 11: water
#              precision    recall  f1-score   support
#
#           0       0.98      0.98      0.98      6143
#           1       0.73      0.64      0.68       411
#
# avg / total       0.96      0.96      0.96      6554
#
# Feature 12: food
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97      5812
#           1       0.78      0.65      0.71       742
#
# avg / total       0.94      0.94      0.94      6554
#
# Feature 13: shelter
#              precision    recall  f1-score   support
#
#           0       0.95      0.99      0.97      5966
#           1       0.81      0.51      0.63       588
#
# avg / total       0.94      0.95      0.94      6554
#
# Feature 14: clothing
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6463
#           1       0.68      0.31      0.42        91
#
# avg / total       0.99      0.99      0.99      6554
#
# Feature 15: money
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.99      6409
#           1       0.52      0.25      0.34       145
#
# avg / total       0.97      0.98      0.97      6554
#
# Feature 16: missing_people
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6487
#           1       0.63      0.18      0.28        67
#
# avg / total       0.99      0.99      0.99      6554
#
# Feature 17: refugees
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98      6341
#           1       0.55      0.26      0.36       213
#
# avg / total       0.96      0.97      0.96      6554
#
# Feature 18: death
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98      6278
#           1       0.74      0.46      0.57       276
#
# avg / total       0.97      0.97      0.97      6554
#
# Feature 19: other_aid
#              precision    recall  f1-score   support
#
#           0       0.89      0.98      0.93      5702
#           1       0.50      0.16      0.24       852
#
# avg / total       0.84      0.87      0.84      6554
#
# Feature 20: infrastructure_related
#              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.97      6137
#           1       0.39      0.09      0.14       417
#
# avg / total       0.91      0.93      0.91      6554
#
# Feature 21: transport
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.98      6254
#           1       0.65      0.20      0.30       300
#
# avg / total       0.95      0.96      0.95      6554
#
# Feature 22: buildings
#              precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98      6218
#           1       0.68      0.43      0.52       336
#
# avg / total       0.95      0.96      0.96      6554
#
# Feature 23: electricity
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6422
#           1       0.59      0.26      0.36       132
#
# avg / total       0.98      0.98      0.98      6554
#
# Feature 24: tools
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6509
#           1       0.14      0.02      0.04        45
#
# avg / total       0.99      0.99      0.99      6554
#
# Feature 25: hospitals
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6470
#           1       0.35      0.08      0.13        84
#
# avg / total       0.98      0.99      0.98      6554
#
# Feature 26: shops
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6532
#           1       0.00      0.00      0.00        22
#
# avg / total       0.99      1.00      0.99      6554
#
# Feature 27: aid_centers
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6482
#           1       0.40      0.11      0.17        72
#
# avg / total       0.98      0.99      0.99      6554
#
# Feature 28: other_infrastructure
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.98      6286
#           1       0.38      0.10      0.16       268
#
# avg / total       0.94      0.96      0.94      6554
#
# Feature 29: weather_related
#              precision    recall  f1-score   support
#
#           0       0.88      0.96      0.92      4732
#           1       0.86      0.66      0.75      1822
#
# avg / total       0.87      0.88      0.87      6554
#
# Feature 30: floods
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.98      6008
#           1       0.84      0.55      0.66       546
#
# avg / total       0.95      0.95      0.95      6554
#
# Feature 31: storm
#              precision    recall  f1-score   support
#
#           0       0.95      0.99      0.97      5970
#           1       0.77      0.51      0.61       584
#
# avg / total       0.94      0.94      0.94      6554
#
# Feature 32: fire
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6468
#           1       0.44      0.14      0.21        86
#
# avg / total       0.98      0.99      0.98      6554
#
# Feature 33: earthquake
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98      5942
#           1       0.87      0.79      0.83       612
#
# avg / total       0.97      0.97      0.97      6554
#
# Feature 34: cold
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6422
#           1       0.65      0.30      0.41       132
#
# avg / total       0.98      0.98      0.98      6554
#
# Feature 35: other_weather
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.97      6222
#           1       0.45      0.17      0.25       332
#
# avg / total       0.93      0.95      0.94      6554
#
# Feature 36: direct_report
#              precision    recall  f1-score   support
#
#           0       0.87      0.96      0.91      5264
#           1       0.73      0.41      0.52      1290
#
# avg / total       0.84      0.85      0.84      6554
#
# The model accuracy is 0.948
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
parameters_rfc = {
        'tfidf__use_idf': (True, False),
        'clf__estimator__n_estimators': [10, 20]
}

cv_rfc = GridSearchCV(pipeline_rfc, param_grid = parameters_rfc)
cv_rfc
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=1))]),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'tfidf__use_idf': (True, False), 'clf__estimator__n_estimators': [10, 20]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
# Fit the first tuned model
cv_rfc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=1))]),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'tfidf__use_idf': (True, False), 'clf__estimator__n_estimators': [10, 20]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
# Prediction: the GridCV tuned
y_pred = cv_rfc.predict(X_test)
plot_scores(y_test, y_pred)
# Out:
# Feature 1: related
#              precision    recall  f1-score   support
#
#           0       0.66      0.43      0.52      1536
#           1       0.84      0.93      0.88      4979
#           2       0.21      0.51      0.30        39
#
# avg / total       0.80      0.81      0.79      6554
#
# Feature 2: request
#              precision    recall  f1-score   support
#
#           0       0.89      0.98      0.94      5409
#           1       0.84      0.45      0.59      1145
#
# avg / total       0.88      0.89      0.88      6554
#
# Feature 3: offer
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6528
#           1       0.00      0.00      0.00        26
#
# avg / total       0.99      1.00      0.99      6554
#
# Feature 4: aid_related
#              precision    recall  f1-score   support
#
#           0       0.78      0.84      0.81      3844
#           1       0.75      0.66      0.70      2710
#
# avg / total       0.77      0.77      0.76      6554
#
# Feature 5: medical_help
#              precision    recall  f1-score   support
#
#           0       0.92      1.00      0.96      6021
#           1       0.64      0.08      0.14       533
#
# avg / total       0.90      0.92      0.89      6554
#
# Feature 6: medical_products
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6245
#           1       0.83      0.06      0.11       309
#
# avg / total       0.95      0.96      0.94      6554
#
# Feature 7: search_and_rescue
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.99      6361
#           1       0.65      0.07      0.12       193
#
# avg / total       0.96      0.97      0.96      6554
#
# Feature 8: security
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6423
#           1       0.33      0.01      0.01       131
#
# avg / total       0.97      0.98      0.97      6554
#
# Feature 9: military
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6318
#           1       0.77      0.04      0.08       236
#
# avg / total       0.96      0.97      0.95      6554
#
# Feature 10: child_alone
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# Feature 11: water
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6143
#           1       0.89      0.28      0.43       411
#
# avg / total       0.95      0.95      0.94      6554
#
# Feature 12: food
#              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.96      5812
#           1       0.85      0.53      0.65       742
#
# avg / total       0.93      0.94      0.93      6554
#
# Feature 13: shelter
#              precision    recall  f1-score   support
#
#           0       0.93      0.99      0.96      5966
#           1       0.81      0.28      0.42       588
#
# avg / total       0.92      0.93      0.91      6554
#
# Feature 14: clothing
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6463
#           1       0.83      0.16      0.28        91
#
# avg / total       0.99      0.99      0.98      6554
#
# Feature 15: money
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6409
#           1       1.00      0.03      0.07       145
#
# avg / total       0.98      0.98      0.97      6554
#
# Feature 16: missing_people
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6487
#           1       0.00      0.00      0.00        67
#
# avg / total       0.98      0.99      0.98      6554
#
# Feature 17: refugees
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6341
#           1       0.69      0.16      0.26       213
#
# avg / total       0.96      0.97      0.96      6554
#
# Feature 18: death
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6278
#           1       0.78      0.14      0.24       276
#
# avg / total       0.96      0.96      0.95      6554
#
# Feature 19: other_aid
#              precision    recall  f1-score   support
#
#           0       0.88      0.99      0.93      5702
#           1       0.60      0.06      0.11       852
#
# avg / total       0.84      0.87      0.82      6554
#
# Feature 20: infrastructure_related
#              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6137
#           1       0.00      0.00      0.00       417
#
# avg / total       0.88      0.94      0.91      6554
#
# Feature 21: transport
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6254
#           1       0.61      0.04      0.07       300
#
# avg / total       0.94      0.95      0.94      6554
#
# Feature 22: buildings
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6218
#           1       0.68      0.12      0.21       336
#
# avg / total       0.94      0.95      0.94      6554
#
# Feature 23: electricity
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6422
#           1       0.67      0.03      0.06       132
#
# avg / total       0.97      0.98      0.97      6554
#
# Feature 24: tools
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6509
#           1       0.00      0.00      0.00        45
#
# avg / total       0.99      0.99      0.99      6554
#
# Feature 25: hospitals
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6470
#           1       0.00      0.00      0.00        84
#
# avg / total       0.97      0.99      0.98      6554
#
# Feature 26: shops
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6532
#           1       0.00      0.00      0.00        22
#
# avg / total       0.99      1.00      0.99      6554
#
# Feature 27: aid_centers
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6482
#           1       0.00      0.00      0.00        72
#
# avg / total       0.98      0.99      0.98      6554
#
# Feature 28: other_infrastructure
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6286
#           1       0.12      0.00      0.01       268
#
# avg / total       0.93      0.96      0.94      6554
#
# Feature 29: weather_related
#              precision    recall  f1-score   support
#
#           0       0.87      0.96      0.91      4732
#           1       0.85      0.64      0.73      1822
#
# avg / total       0.87      0.87      0.86      6554
#
# Feature 30: floods
#              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6008
#           1       0.90      0.36      0.51       546
#
# avg / total       0.94      0.94      0.93      6554
#
# Feature 31: storm
#              precision    recall  f1-score   support
#
#           0       0.95      0.99      0.97      5970
#           1       0.80      0.41      0.54       584
#
# avg / total       0.93      0.94      0.93      6554
#
# Feature 32: fire
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6468
#           1       0.00      0.00      0.00        86
#
# avg / total       0.97      0.99      0.98      6554
#
# Feature 33: earthquake
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98      5942
#           1       0.88      0.76      0.82       612
#
# avg / total       0.97      0.97      0.97      6554
#
# Feature 34: cold
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6422
#           1       1.00      0.11      0.19       132
#
# avg / total       0.98      0.98      0.97      6554
#
# Feature 35: other_weather
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6222
#           1       0.51      0.06      0.10       332
#
# avg / total       0.93      0.95      0.93      6554
#
# Feature 36: direct_report
#              precision    recall  f1-score   support
#
#           0       0.86      0.98      0.92      5264
#           1       0.78      0.36      0.49      1290
#
# avg / total       0.85      0.85      0.83      6554
#
# The model accuracy is 0.946
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
# Create a pickle file for the model
file_name = 'classifier.pkl'
with open (file_name, 'wb') as f:
    pickle.dump(cv_rfc, f)

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
